# %%
# !pip install spacy
# Out:
# Collecting spacy
#   Obtaining dependency information for spacy from https://files.pythonhosted.org/packages/89/70/9a54469cf5263d4e4079b329458492a1e150810587b7c82961bee208cfa5/spacy-3.7.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached spacy-3.7.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (27 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/conda/lib/python3.11/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.11/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.11/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.11/site-packages (from spacy) (3.0.8)
# Collecting thinc<8.3.0,>=8.2.2 (from spacy)
#   Obtaining dependency information for thinc<8.3.0,>=8.2.2 from https://files.pythonhosted.org/packages/1a/19/cd73e3b5f22d5d9399f6f2931ab0fb985415f34030dcfead070181866761/thinc-8.2.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached thinc-8.2.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/conda/lib/python3.11/site-packages (from spacy) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/conda/lib/python3.11/site-packages (from spacy) (2.4.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/conda/lib/python3.11/site-packages (from spacy) (2.0.9)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /opt/conda/lib/python3.11/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /opt/conda/lib/python3.11/site-packages (from spacy) (0.3.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.11/site-packages (from spacy) (4.66.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.11/site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/conda/lib/python3.11/site-packages (from spacy) (1.8.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from spacy) (68.1.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/conda/lib/python3.11/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /opt/conda/lib/python3.11/site-packages (from spacy) (1.24.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/conda/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/conda/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.3)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /opt/conda/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /opt/conda/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /opt/conda/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->spacy) (2.1.3)
# Using cached spacy-3.7.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.5 MB)
# Using cached thinc-8.2.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (920 kB)
# Installing collected packages: thinc, spacy
#   Attempting uninstall: thinc
#     Found existing installation: thinc 9.0.0
#     Uninstalling thinc-9.0.0:
#       Successfully uninstalled thinc-9.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# zh-core-web-sm 3.0.0 requires spacy<3.1.0,>=3.0.0, but you have spacy 3.7.6 which is incompatible.
# Successfully installed spacy-3.7.6 thinc-8.2.5

# %%
# !pip install https://github.com/explosion/spacy-models/releases/download/zh_core_web_sm-3.0.0/zh_core_web_sm-3.0.0.tar.gz
# Out:
# Collecting https://github.com/explosion/spacy-models/releases/download/zh_core_web_sm-3.0.0/zh_core_web_sm-3.0.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/zh_core_web_sm-3.0.0/zh_core_web_sm-3.0.0.tar.gz (49.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 MB 24.4 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting spacy<3.1.0,>=3.0.0 (from zh-core-web-sm==3.0.0)
#   Using cached spacy-3.0.9-cp311-cp311-linux_x86_64.whl
# Requirement already satisfied: spacy-pkuseg<0.1.0,>=0.0.27 in /opt/conda/lib/python3.11/site-packages (from zh-core-web-sm==3.0.0) (0.0.33)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.5 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (3.0.12)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (3.0.8)
# Collecting thinc<8.1.0,>=8.0.3 (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0)
#   Using cached thinc-8.0.17-cp311-cp311-linux_x86_64.whl
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (0.7.10)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (2.4.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (2.0.9)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (0.3.2)
# Requirement already satisfied: pathy>=0.3.5 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (1.24.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (1.8.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (3.1.2)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (68.1.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (23.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (2023.7.22)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /opt/conda/lib/python3.11/site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (2.1.3)
# Installing collected packages: thinc, spacy
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.2.5
#     Uninstalling thinc-8.2.5:
#       Successfully uninstalled thinc-8.2.5
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.7.6
#     Uninstalling spacy-3.7.6:
#       Successfully uninstalled spacy-3.7.6
# Successfully installed spacy-3.0.9 thinc-8.0.17

# %%
import spacy

# 测试加载中文模型
nlp = spacy.load('zh_core_web_sm')
print("spaCy 和 中文模型加载成功！")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import spacy
#       3 # 测试加载中文模型
#       4 nlp = spacy.load('zh_core_web_sm')
#
# File /opt/conda/lib/python3.11/site-packages/spacy/__init__.py:13
#      10 from thinc.api import prefer_gpu, require_gpu, require_cpu  # noqa: F401
#      11 from thinc.api import Config
# ---> 13 from . import pipeline  # noqa: F401
#      14 from .cli.info import info  # noqa: F401
#      15 from .glossary import explain  # noqa: F401
#
# File /opt/conda/lib/python3.11/site-packages/spacy/pipeline/__init__.py:1
# ----> 1 from .attributeruler import AttributeRuler
#       2 from .dep_parser import DependencyParser
#       3 from .entity_linker import EntityLinker
#
# File /opt/conda/lib/python3.11/site-packages/spacy/pipeline/attributeruler.py:6
#       3 import srsly
#       4 from pathlib import Path
# ----> 6 from .pipe import Pipe
#       7 from ..errors import Errors
#       8 from ..training import validate_examples, Example
#
# File /opt/conda/lib/python3.11/site-packages/spacy/pipeline/pipe.pyx:8, in init spacy.pipeline.pipe()
#
# File /opt/conda/lib/python3.11/site-packages/spacy/training/__init__.py:11
#       9 from .batchers import minibatch_by_padded_size, minibatch_by_words  # noqa: F401
#      10 from .loggers import console_logger, wandb_logger  # noqa: F401
# ---> 11 from .callbacks import create_copy_from_base_model  # noqa: F401
#
# File /opt/conda/lib/python3.11/site-packages/spacy/training/callbacks.py:3
#       1 from typing import Optional
#       2 from ..errors import Errors
# ----> 3 from ..language import Language
#       4 from ..util import load_model, registry, logger
#       7 @registry.callbacks("spacy.copy_from_base_model.v1")
#       8 def create_copy_from_base_model(
#       9     tokenizer: Optional[str] = None,
#      10     vocab: Optional[str] = None,
#      11 ) -> Language:
#
# File /opt/conda/lib/python3.11/site-packages/spacy/language.py:22
#      20 from .pipe_analysis import validate_attrs, analyze_pipes, print_pipe_analysis
#      21 from .training import Example, validate_examples
# ---> 22 from .training.initialize import init_vocab, init_tok2vec
#      23 from .scorer import Scorer
#      24 from .util import registry, SimpleFrozenList, _pipe, raise_error
#
# File /opt/conda/lib/python3.11/site-packages/spacy/training/initialize.py:13
#      10 import tqdm
#      11 from itertools import islice
# ---> 13 from .pretrain import get_tok2vec_ref
#      14 from ..lookups import Lookups
#      15 from ..vectors import Vectors
#
# File /opt/conda/lib/python3.11/site-packages/spacy/training/pretrain.py:16
#      14 from ..errors import Errors
#      15 from ..tokens import Doc
# ---> 16 from ..schemas import ConfigSchemaPretrain
#      17 from ..util import registry, load_model_from_config, dot_to_object
#      20 def pretrain(
#      21     config: Config,
#      22     output_dir: Path,
#    (...)
#      26     silent: bool = True,
#      27 ):
#
# File /opt/conda/lib/python3.11/site-packages/spacy/schemas.py:156
#     152         obj = converted
#     153     return validate(TokenPatternSchema, {"pattern": obj})
# --> 156 class TokenPatternString(BaseModel):
#     157     REGEX: Optional[StrictStr] = Field(None, alias="regex")
#     158     IN: Optional[List[StrictStr]] = Field(None, alias="in")
#
# File /opt/conda/lib/python3.11/site-packages/pydantic/main.py:369, in ModelMetaclass.__new__(mcs, name, bases, namespace, **kwargs)
#     367 cls = super().__new__(mcs, name, bases, new_namespace, **kwargs)
#     368 # set __signature__ attr only for model class, but not for its instances
# --> 369 cls.__signature__ = ClassAttribute('__signature__', generate_model_signature(cls.__init__, fields, config))
#     370 return cls
#
# File /opt/conda/lib/python3.11/site-packages/pydantic/utils.py:231, in generate_model_signature(init, fields, config)
#     229         # TODO: replace annotation with actual expected types once #1055 solved
#     230         kwargs = {'default': field.default} if not field.required else {}
# --> 231         merged_params[param_name] = Parameter(
#     232             param_name, Parameter.KEYWORD_ONLY, annotation=field.outer_type_, **kwargs
#     233         )
#     235 if config.extra is config.extra.allow:
#     236     use_var_kw = True
#
# File /opt/conda/lib/python3.11/inspect.py:2725, in Parameter.__init__(self, name, kind, default, annotation)
#    2723 is_keyword = iskeyword(name) and self._kind is not _POSITIONAL_ONLY
#    2724 if is_keyword or not name.isidentifier():
# -> 2725     raise ValueError('{!r} is not a valid parameter name'.format(name))
#    2727 self._name = name
#
# ValueError: 'in' is not a valid parameter name

# %%
# !pip uninstall -y spacy pydantic thinc
# Out:
# Found existing installation: spacy 3.0.9
# Uninstalling spacy-3.0.9:
#   Successfully uninstalled spacy-3.0.9
# Found existing installation: pydantic 1.8.2
# Uninstalling pydantic-1.8.2:
#   Successfully uninstalled pydantic-1.8.2
# Found existing installation: thinc 8.0.17
# Uninstalling thinc-8.0.17:
#   Successfully uninstalled thinc-8.0.17

# %%
# !pip install pydantic==1.8.2
# !pip install spacy==3.0.0
# !pip install thinc==8.0.0
# Out:
# Collecting pydantic==1.8.2
#   Obtaining dependency information for pydantic==1.8.2 from https://files.pythonhosted.org/packages/ff/74/54e030641601112309f6d2af620774e9080f99c7a15742fc6a0b170c4076/pydantic-1.8.2-py3-none-any.whl.metadata
#   Using cached pydantic-1.8.2-py3-none-any.whl.metadata (103 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.11/site-packages (from pydantic==1.8.2) (4.7.1)
# Using cached pydantic-1.8.2-py3-none-any.whl (126 kB)
# Installing collected packages: pydantic
# Successfully installed pydantic-1.8.2
# Collecting spacy==3.0.0
#   Using cached spacy-3.0.0.tar.gz (7.0 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [167 lines of output]
#       Copied /tmp/pip-install-83t0o9lm/spacy_01160b875f614438a70dd006c90dd9f1/setup.cfg -> /tmp/pip-install-83t0o9lm/spacy_01160b875f614438a70dd006c90dd9f1/spacy/tests/package
#       Copied /tmp/pip-install-83t0o9lm/spacy_01160b875f614438a70dd006c90dd9f1/pyproject.toml -> /tmp/pip-install-83t0o9lm/spacy_01160b875f614438a70dd006c90dd9f1/spacy/tests/package
#       Cythonizing sources
#       Compiling spacy/training/example.pyx because it changed.
#       Compiling spacy/parts_of_speech.pyx because it changed.
#       Compiling spacy/strings.pyx because it changed.
#       Compiling spacy/lexeme.pyx because it changed.
#       Compiling spacy/vocab.pyx because it changed.
#       Compiling spacy/attrs.pyx because it changed.
#       Compiling spacy/kb.pyx because it changed.
#       Compiling spacy/ml/parser_model.pyx because it changed.
#       Compiling spacy/morphology.pyx because it changed.
#       Compiling spacy/pipeline/dep_parser.pyx because it changed.
#       Compiling spacy/pipeline/morphologizer.pyx because it changed.
#       Compiling spacy/pipeline/multitask.pyx because it changed.
#       Compiling spacy/pipeline/ner.pyx because it changed.
#       Compiling spacy/pipeline/pipe.pyx because it changed.
#       Compiling spacy/pipeline/trainable_pipe.pyx because it changed.
#       Compiling spacy/pipeline/sentencizer.pyx because it changed.
#       Compiling spacy/pipeline/senter.pyx because it changed.
#       Compiling spacy/pipeline/tagger.pyx because it changed.
#       Compiling spacy/pipeline/transition_parser.pyx because it changed.
#       Compiling spacy/pipeline/_parser_internals/arc_eager.pyx because it changed.
#       Compiling spacy/pipeline/_parser_internals/ner.pyx because it changed.
#       Compiling spacy/pipeline/_parser_internals/nonproj.pyx because it changed.
#       Compiling spacy/pipeline/_parser_internals/_state.pyx because it changed.
#       Compiling spacy/pipeline/_parser_internals/stateclass.pyx because it changed.
#       Compiling spacy/pipeline/_parser_internals/transition_system.pyx because it changed.
#       Compiling spacy/pipeline/_parser_internals/_beam_utils.pyx because it changed.
#       Compiling spacy/tokenizer.pyx because it changed.
#       Compiling spacy/training/align.pyx because it changed.
#       Compiling spacy/training/gold_io.pyx because it changed.
#       Compiling spacy/tokens/doc.pyx because it changed.
#       Compiling spacy/tokens/span.pyx because it changed.
#       Compiling spacy/tokens/token.pyx because it changed.
#       Compiling spacy/tokens/span_group.pyx because it changed.
#       Compiling spacy/tokens/graph.pyx because it changed.
#       Compiling spacy/tokens/morphanalysis.pyx because it changed.
#       Compiling spacy/tokens/_retokenize.pyx because it changed.
#       Compiling spacy/matcher/matcher.pyx because it changed.
#       Compiling spacy/matcher/phrasematcher.pyx because it changed.
#       Compiling spacy/matcher/dependencymatcher.pyx because it changed.
#       Compiling spacy/symbols.pyx because it changed.
#       Compiling spacy/vectors.pyx because it changed.
#       [ 1/41] Cythonizing spacy/attrs.pyx
#       [ 2/41] Cythonizing spacy/kb.pyx
#
#       Error compiling Cython file:
#       ------------------------------------------------------------
#       ...
#           int length
#
#
#       cdef class Vocab:
#           cdef Pool mem
#           cpdef readonly StringStore strings
#                 ^
#       ------------------------------------------------------------
#
#       spacy/vocab.pxd:28:10: Variables cannot be declared with 'cpdef'. Use 'cdef' instead.
#
#       Error compiling Cython file:
#       ------------------------------------------------------------
#       ...
#
#
#       cdef class Vocab:
#           cdef Pool mem
#           cpdef readonly StringStore strings
#           cpdef public Morphology morphology
#                 ^
#       ------------------------------------------------------------
#
#       spacy/vocab.pxd:29:10: Variables cannot be declared with 'cpdef'. Use 'cdef' instead.
#
#       Error compiling Cython file:
#       ------------------------------------------------------------
#       ...
#
#       cdef class Vocab:
#           cdef Pool mem
#           cpdef readonly StringStore strings
#           cpdef public Morphology morphology
#           cpdef public object vectors
#                 ^
#       ------------------------------------------------------------
#
#       spacy/vocab.pxd:30:10: Variables cannot be declared with 'cpdef'. Use 'cdef' instead.
#
#       Error compiling Cython file:
#       ------------------------------------------------------------
#       ...
#       cdef class Vocab:
#           cdef Pool mem
#           cpdef readonly StringStore strings
#           cpdef public Morphology morphology
#           cpdef public object vectors
#           cpdef public object _lookups
#                 ^
#       ------------------------------------------------------------
#
#       spacy/vocab.pxd:31:10: Variables cannot be declared with 'cpdef'. Use 'cdef' instead.
#
#       Error compiling Cython file:
#       ------------------------------------------------------------
#       ...
#           cdef Pool mem
#           cpdef readonly StringStore strings
#           cpdef public Morphology morphology
#           cpdef public object vectors
#           cpdef public object _lookups
#           cpdef public object writing_system
#                 ^
#       ------------------------------------------------------------
#
#       spacy/vocab.pxd:32:10: Variables cannot be declared with 'cpdef'. Use 'cdef' instead.
#
#       Error compiling Cython file:
#       ------------------------------------------------------------
#       ...
#           cpdef readonly StringStore strings
#           cpdef public Morphology morphology
#           cpdef public object vectors
#           cpdef public object _lookups
#           cpdef public object writing_system
#           cpdef public object get_noun_chunks
#                 ^
#       ------------------------------------------------------------
#
#       spacy/vocab.pxd:33:10: Variables cannot be declared with 'cpdef'. Use 'cdef' instead.
#
#       Error compiling Cython file:
#       ------------------------------------------------------------
#       ...
#           cdef float prior_prob
#
#
#       cdef class KnowledgeBase:
#           cdef Pool mem
#           cpdef readonly Vocab vocab
#                 ^
#       ------------------------------------------------------------
#
#       spacy/kb.pxd:31:10: Variables cannot be declared with 'cpdef'. Use 'cdef' instead.
#       Traceback (most recent call last):
#         File "/opt/conda/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#         File "/opt/conda/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/opt/conda/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 118, in get_requires_for_build_wheel
#           return hook(config_settings)
#                  ^^^^^^^^^^^^^^^^^^^^^
#         File "/tmp/pip-build-env-bfv2qomr/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 332, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=[])
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/tmp/pip-build-env-bfv2qomr/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 302, in _get_build_requires
#           self.run_setup()
#         File "/tmp/pip-build-env-bfv2qomr/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 318, in run_setup
#           exec(code, locals())
#         File "<string>", line 225, in <module>
#         File "<string>", line 211, in setup_package
#         File "/tmp/pip-build-env-bfv2qomr/overlay/lib/python3.11/site-packages/Cython/Build/Dependencies.py", line 1154, in cythonize
#           cythonize_one(*args)
#         File "/tmp/pip-build-env-bfv2qomr/overlay/lib/python3.11/site-packages/Cython/Build/Dependencies.py", line 1321, in cythonize_one
#           raise CompileError(None, pyx_file)
#       Cython.Compiler.Errors.CompileError: spacy/kb.pyx
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Collecting thinc==8.0.0
#   Downloading thinc-8.0.0.tar.gz (619 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.4/619.4 kB 2.3 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from thinc==8.0.0) (0.7.10)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.11/site-packages (from thinc==8.0.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.11/site-packages (from thinc==8.0.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.11/site-packages (from thinc==8.0.0) (3.0.8)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from thinc==8.0.0) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from thinc==8.0.0) (2.4.7)
# Requirement already satisfied: catalogue<3.0.0,>=0.2.0 in /opt/conda/lib/python3.11/site-packages (from thinc==8.0.0) (2.0.9)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from thinc==8.0.0) (68.1.2)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/lib/python3.11/site-packages (from thinc==8.0.0) (1.24.4)
# Collecting pydantic<1.8.0,>=1.7.1 (from thinc==8.0.0)
#   Obtaining dependency information for pydantic<1.8.0,>=1.7.1 from https://files.pythonhosted.org/packages/ed/12/72633da8bf0428fd0a7d2915073f4bc03fcdc2ebc0f703e56af597ac45db/pydantic-1.7.4-py3-none-any.whl.metadata
#   Downloading pydantic-1.7.4-py3-none-any.whl.metadata (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 kB 9.3 MB/s eta 0:00:00
# Downloading pydantic-1.7.4-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.9/107.9 kB 9.9 MB/s eta 0:00:00
# Building wheels for collected packages: thinc
#   Building wheel for thinc (pyproject.toml) ... done
#   Created wheel for thinc: filename=thinc-8.0.0-cp311-cp311-linux_x86_64.whl size=1281057 sha256=d7bcfe2d5fff9b44976d9772ac14630bf4adb5811d3819077079bf53e8cb3a4e
#   Stored in directory: /home/jovyan/.cache/pip/wheels/73/9f/a1/184d4ca95ee9053fb30148469cee071d853348dbdff28b9b2f
# Successfully built thinc
# Installing collected packages: pydantic, thinc
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.8.2
#     Uninstalling pydantic-1.8.2:
#       Successfully uninstalled pydantic-1.8.2
# Successfully installed pydantic-1.7.4 thinc-8.0.0

# %%
pip install https://github.com/explosion/spacy-models/releases/download/zh_core_web_sm-3.0.0/zh_core_web_sm-3.0.0.tar.gz
# Out:
# Collecting https://github.com/explosion/spacy-models/releases/download/zh_core_web_sm-3.0.0/zh_core_web_sm-3.0.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/zh_core_web_sm-3.0.0/zh_core_web_sm-3.0.0.tar.gz (49.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 MB 26.3 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting spacy<3.1.0,>=3.0.0 (from zh-core-web-sm==3.0.0)
#   Using cached spacy-3.0.9-cp311-cp311-linux_x86_64.whl
# Requirement already satisfied: spacy-pkuseg<0.1.0,>=0.0.27 in /opt/conda/lib/python3.11/site-packages (from zh-core-web-sm==3.0.0) (0.0.33)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.5 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (3.0.12)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (3.0.8)
# Collecting thinc<8.1.0,>=8.0.3 (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0)
#   Using cached thinc-8.0.17-cp311-cp311-linux_x86_64.whl
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (0.7.10)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (2.4.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (2.0.9)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (0.3.2)
# Requirement already satisfied: pathy>=0.3.5 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (1.24.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (1.7.4)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (3.1.2)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (68.1.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (2023.7.22)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /opt/conda/lib/python3.11/site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->spacy<3.1.0,>=3.0.0->zh-core-web-sm==3.0.0) (2.1.3)
# Installing collected packages: thinc, spacy
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.0.0
#     Uninstalling thinc-8.0.0:
#       Successfully uninstalled thinc-8.0.0
# Successfully installed spacy-3.0.9 thinc-8.0.17
# Note: you may need to restart the kernel to use updated packages.

# %%
import spacy

# 测试加载中文模型
nlp = spacy.load('zh_core_web_sm')
print("spaCy 和 中文模型加载成功！")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import spacy
#       3 # 测试加载中文模型
#       4 nlp = spacy.load('zh_core_web_sm')
#
# File /opt/conda/lib/python3.11/site-packages/spacy/__init__.py:13
#      10 from thinc.api import prefer_gpu, require_gpu, require_cpu  # noqa: F401
#      11 from thinc.api import Config
# ---> 13 from . import pipeline  # noqa: F401
#      14 from .cli.info import info  # noqa: F401
#      15 from .glossary import explain  # noqa: F401
#
# File /opt/conda/lib/python3.11/site-packages/spacy/pipeline/__init__.py:1
# ----> 1 from .attributeruler import AttributeRuler
#       2 from .dep_parser import DependencyParser
#       3 from .entity_linker import EntityLinker
#
# File /opt/conda/lib/python3.11/site-packages/spacy/pipeline/attributeruler.py:6
#       3 import srsly
#       4 from pathlib import Path
# ----> 6 from .pipe import Pipe
#       7 from ..errors import Errors
#       8 from ..training import validate_examples, Example
#
# File /opt/conda/lib/python3.11/site-packages/spacy/pipeline/pipe.pyx:8, in init spacy.pipeline.pipe()
#
# File /opt/conda/lib/python3.11/site-packages/spacy/training/__init__.py:11
#       9 from .batchers import minibatch_by_padded_size, minibatch_by_words  # noqa: F401
#      10 from .loggers import console_logger, wandb_logger  # noqa: F401
# ---> 11 from .callbacks import create_copy_from_base_model  # noqa: F401
#
# File /opt/conda/lib/python3.11/site-packages/spacy/training/callbacks.py:3
#       1 from typing import Optional
#       2 from ..errors import Errors
# ----> 3 from ..language import Language
#       4 from ..util import load_model, registry, logger
#       7 @registry.callbacks("spacy.copy_from_base_model.v1")
#       8 def create_copy_from_base_model(
#       9     tokenizer: Optional[str] = None,
#      10     vocab: Optional[str] = None,
#      11 ) -> Language:
#
# File /opt/conda/lib/python3.11/site-packages/spacy/language.py:22
#      20 from .pipe_analysis import validate_attrs, analyze_pipes, print_pipe_analysis
#      21 from .training import Example, validate_examples
# ---> 22 from .training.initialize import init_vocab, init_tok2vec
#      23 from .scorer import Scorer
#      24 from .util import registry, SimpleFrozenList, _pipe, raise_error
#
# File /opt/conda/lib/python3.11/site-packages/spacy/training/initialize.py:13
#      10 import tqdm
#      11 from itertools import islice
# ---> 13 from .pretrain import get_tok2vec_ref
#      14 from ..lookups import Lookups
#      15 from ..vectors import Vectors
#
# File /opt/conda/lib/python3.11/site-packages/spacy/training/pretrain.py:16
#      14 from ..errors import Errors
#      15 from ..tokens import Doc
# ---> 16 from ..schemas import ConfigSchemaPretrain
#      17 from ..util import registry, load_model_from_config, dot_to_object
#      20 def pretrain(
#      21     config: Config,
#      22     output_dir: Path,
#    (...)
#      26     silent: bool = True,
#      27 ):
#
# File /opt/conda/lib/python3.11/site-packages/spacy/schemas.py:156
#     152         obj = converted
#     153     return validate(TokenPatternSchema, {"pattern": obj})
# --> 156 class TokenPatternString(BaseModel):
#     157     REGEX: Optional[StrictStr] = Field(None, alias="regex")
#     158     IN: Optional[List[StrictStr]] = Field(None, alias="in")
#
# File /opt/conda/lib/python3.11/site-packages/pydantic/main.py:326, in ModelMetaclass.__new__(mcs, name, bases, namespace, **kwargs)
#     324 cls = super().__new__(mcs, name, bases, new_namespace, **kwargs)
#     325 # set __signature__ attr only for model class, but not for its instances
# --> 326 cls.__signature__ = ClassAttribute('__signature__', generate_model_signature(cls.__init__, fields, config))
#     327 return cls
#
# File /opt/conda/lib/python3.11/site-packages/pydantic/utils.py:225, in generate_model_signature(init, fields, config)
#     223         # TODO: replace annotation with actual expected types once #1055 solved
#     224         kwargs = {'default': field.default} if not field.required else {}
# --> 225         merged_params[param_name] = Parameter(
#     226             param_name, Parameter.KEYWORD_ONLY, annotation=field.outer_type_, **kwargs
#     227         )
#     229 if config.extra is config.extra.allow:
#     230     use_var_kw = True
#
# File /opt/conda/lib/python3.11/inspect.py:2725, in Parameter.__init__(self, name, kind, default, annotation)
#    2723 is_keyword = iskeyword(name) and self._kind is not _POSITIONAL_ONLY
#    2724 if is_keyword or not name.isidentifier():
# -> 2725     raise ValueError('{!r} is not a valid parameter name'.format(name))
#    2727 self._name = name
#
# ValueError: 'in' is not a valid parameter name
